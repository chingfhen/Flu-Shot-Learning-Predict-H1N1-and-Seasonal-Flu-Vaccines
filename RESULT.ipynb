# %% [markdown]
# # Best Score: 0.8618 AUC
# - stacking classifier achieved a best score of 0.8618 AUC ; ranked in the top 5% as of Aug 2021
# - future projects could **investigate the use of different final estimators** ; only Logistic regression has been used

# %%
from IPython.display import Image
Image(r"C:\Users\tanch\Documents\Coding Competitions\DataDriven\Flu Shot Learning\local\RAM\Stacked 1.PNG")
