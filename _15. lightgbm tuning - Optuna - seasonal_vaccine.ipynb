# %% [markdown]
# # About:
# - this notebooks:
#     - optimizes parameters with Optuna with a pruner that observes intermediate results and stop unpromising trials.
#     - Approach:
#         1. Fix at a high-ish learning rate and at a fixed iteration
#         2. perform Hyperparameter Search
#         3. Using the best parameters found, reduce learning rate and find the best iteration using early stopping
# - insights:
#     - **the above approach is effective** - gains are usually seen in step 3

# %%
import lightgbm as lgb
import optuna 
from lightgbm import Dataset
from optuna import Trial, visualization
from optuna.samplers import TPESampler

# %% [markdown]
# ### prepare data

# %%
label_colnames = ['h1n1_vaccine', 'seasonal_vaccine']
X = pd.read_csv(r"C:\Users\tanch\Documents\Coding Competitions\DataDriven\Flu Shot Learning\local\data\cleaned_train_set.csv",index_col = "respondent_id")
y = X[label_colnames[1]]
X = X.drop(label_colnames,axis=1)

# %%
# boosting libraries have Dataset class that has memory and speed optimizations
dtrain = Dataset(X, label=y)

# %% [markdown]
# # Objective Function
# - should take an input Trial instance and return a score

# %%
def objective(trial):

    # n_estimators and learning rate are closely tight and will be tuned afterwards
    param = {
        "objective": "binary",
        "learning_rate":0.1,
        "metric": "auc",
        "verbosity": -1,
        "boosting_type": "gbdt",
        "max_depth" : trial.suggest_int("max_depth", 4, 10),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.4, 1.0),
        "subsample": trial.suggest_float("subsample", 0.4, 1.0),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
        "lambda_l1": trial.suggest_float("lambda_l1", 1e-8, 10.0, log=True),
        "lambda_l2": trial.suggest_float("lambda_l2", 1e-8, 10.0, log=True),
    }

    # Add a callback for pruning.
    pruning_callback = optuna.integration.LightGBMPruningCallback(trial, "auc")
    
    cv_scores = lgb.cv(param, dtrain, 1000, nfold  = 3, early_stopping_rounds = 20,verbose_eval=False, 
                       callbacks=[pruning_callback])
    
    return cv_scores['auc-mean'][-1]      # last recorded cv score is the best score from early stopping

# %% [markdown]
# # create_study

# %%
study = optuna.create_study(
    pruner=optuna.pruners.MedianPruner(n_warmup_steps=10), direction="maximize"
)
study.optimize(objective, n_trials=1000)
# Out:
# [I 2021-07-29 19:31:26,678] A new study created in memory with name: no-name-61e871c1-26dd-4068-aca6-d64731bf1d3e
# [I 2021-07-29 19:31:27,722] Trial 0 finished with value: 0.8625741011202436 and parameters: {'max_depth': 6, 'colsample_bytree': 0.8448705189311658, 'subsample': 0.6665039870461622, 'min_child_samples': 91, 'lambda_l1': 0.0022255494064781878, 'lambda_l2': 3.987015787570781e-06}. Best is trial 0 with value: 0.8625741011202436.
# [I 2021-07-29 19:31:28,705] Trial 1 finished with value: 0.8624438614770368 and parameters: {'max_depth': 8, 'colsample_bytree': 0.7743214679944873, 'subsample': 0.7322971164747668, 'min_child_samples': 93, 'lambda_l1': 0.29129123918541483, 'lambda_l2': 1.3069648221242424e-06}. Best is trial 0 with value: 0.8625741011202436.
# [I 2021-07-29 19:31:29,656] Trial 2 finished with value: 0.8619219108269903 and parameters: {'max_depth': 10, 'colsample_bytree': 0.9943979148083687, 'subsample': 0.593235949279995, 'min_child_samples': 77, 'lambda_l1': 4.1410816136901324e-05, 'lambda_l2': 0.0076146558223431525}. Best is trial 0 with value: 0.8625741011202436.
# [I 2021-07-29 19:31:30,518] Trial 3 finished with value: 0.8622922698882434 and parameters: {'max_depth': 7, 'colsample_bytree': 0.9154867767975055, 'subsample': 0.6130600357243072, 'min_child_samples': 12, 'lambda_l1': 3.4969088557897006e-06, 'lambda_l2': 2.1824282844827603e-07}. Best is trial 0 with value: 0.8625741011202436.
# [I 2021-07-29 19:31:31,509] Trial 4 finished with value: 0.8631975974217724 and parameters: {'max_depth': 7, 'colsample_bytree': 0.4009737344898821, 'subsample': 0.9492867346282217, 'min_child_samples': 90, 'lambda_l1': 0.49150080955229486, 'lambda_l2': 0.006339156509249312}. Best is trial 4 with value: 0.8631975974217724.
# [I 2021-07-29 19:31:31,678] Trial 5 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:31:31,891] Trial 6 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:31:32,083] Trial 7 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:31:32,246] Trial 8 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:31:33,381] Trial 9 finished with value: 0.8628733057385158 and parameters: {'max_depth': 8, 'colsample_bytree': 0.5921544718067152, 'subsample': 0.9286209625212782, 'min_child_samples': 20, 'lambda_l1': 0.703511724098574, 'lambda_l2': 0.0002939883955097769}. Best is trial 4 with value: 0.8631975974217724.
# [I 2021-07-29 19:31:33,586] Trial 10 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:31:34,871] Trial 11 finished with value: 0.8634175138582297 and parameters: {'max_depth': 9, 'colsample_bytree': 0.577874210491309, 'subsample': 0.9757140913567638, 'min_child_samples': 40, 'lambda_l1': 3.0932668520106406, 'lambda_l2': 0.03746143885117853}. Best is trial 11 with value: 0.8634175138582297.
# [I 2021-07-29 19:31:35,808] Trial 12 finished with value: 0.8630839427107113 and parameters: {'max_depth': 9, 'colsample_bytree': 0.5634669743190411, 'subsample': 0.8422966202960249, 'min_child_samples': 44, 'lambda_l1': 0.010025654919358903, 'lambda_l2': 0.14409383822635405}. Best is trial 11 with value: 0.8634175138582297.
# [I 2021-07-29 19:31:36,108] Trial 13 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:31:36,401] Trial 14 pruned. Trial was pruned at iteration 15.
# [I 2021-07-29 19:31:36,789] Trial 15 pruned. Trial was pruned at iteration 23.
# [I 2021-07-29 19:31:37,062] Trial 16 pruned. Trial was pruned at iteration 15.
# [I 2021-07-29 19:31:37,418] Trial 17 pruned. Trial was pruned at iteration 22.
# [I 2021-07-29 19:31:38,449] Trial 18 finished with value: 0.8629349303400625 and parameters: {'max_depth': 10, 'colsample_bytree': 0.6586690207640612, 'subsample': 0.9881348371892296, 'min_child_samples': 80, 'lambda_l1': 0.0672926889638902, 'lambda_l2': 0.720625102998604}. Best is trial 11 with value: 0.8634175138582297.
# [I 2021-07-29 19:31:38,791] Trial 19 pruned. Trial was pruned at iteration 21.
# [I 2021-07-29 19:31:39,017] Trial 20 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:31:39,610] Trial 21 pruned. Trial was pruned at iteration 51.
# [I 2021-07-29 19:31:39,847] Trial 22 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:31:40,115] Trial 23 pruned. Trial was pruned at iteration 15.
# [I 2021-07-29 19:31:40,506] Trial 24 pruned. Trial was pruned at iteration 23.
# [I 2021-07-29 19:31:40,770] Trial 25 pruned. Trial was pruned at iteration 15.
# [I 2021-07-29 19:31:41,731] Trial 26 finished with value: 0.863170995914032 and parameters: {'max_depth': 8, 'colsample_bytree': 0.5273938915223314, 'subsample': 0.9417891731137402, 'min_child_samples': 39, 'lambda_l1': 0.01509186256567244, 'lambda_l2': 0.005472269867567536}. Best is trial 11 with value: 0.8634175138582297.
# [I 2021-07-29 19:31:42,844] Trial 27 pruned. Trial was pruned at iteration 113.
# [I 2021-07-29 19:31:43,169] Trial 28 pruned. Trial was pruned at iteration 23.
# [I 2021-07-29 19:31:43,429] Trial 29 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:31:44,338] Trial 30 finished with value: 0.8631356861135102 and parameters: {'max_depth': 8, 'colsample_bytree': 0.5328545047556131, 'subsample': 0.7969282745850247, 'min_child_samples': 39, 'lambda_l1': 0.03719237823048772, 'lambda_l2': 0.0005425193641521165}. Best is trial 11 with value: 0.8634175138582297.
# [I 2021-07-29 19:31:44,923] Trial 31 pruned. Trial was pruned at iteration 53.
# [I 2021-07-29 19:31:45,227] Trial 32 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:31:45,925] Trial 33 pruned. Trial was pruned at iteration 65.
# [I 2021-07-29 19:31:46,439] Trial 34 pruned. Trial was pruned at iteration 42.
# [I 2021-07-29 19:31:46,694] Trial 35 pruned. Trial was pruned at iteration 14.
# [I 2021-07-29 19:31:47,020] Trial 36 pruned. Trial was pruned at iteration 22.
# [I 2021-07-29 19:31:47,299] Trial 37 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:31:47,933] Trial 38 pruned. Trial was pruned at iteration 51.
# [I 2021-07-29 19:31:48,268] Trial 39 pruned. Trial was pruned at iteration 19.
# [I 2021-07-29 19:31:48,545] Trial 40 pruned. Trial was pruned at iteration 16.
# [I 2021-07-29 19:31:49,177] Trial 41 pruned. Trial was pruned at iteration 53.
# [I 2021-07-29 19:31:49,682] Trial 42 pruned. Trial was pruned at iteration 42.
# [I 2021-07-29 19:31:49,902] Trial 43 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:31:50,221] Trial 44 pruned. Trial was pruned at iteration 14.
# [I 2021-07-29 19:31:50,467] Trial 45 pruned. Trial was pruned at iteration 12.
# [I 2021-07-29 19:31:51,096] Trial 46 pruned. Trial was pruned at iteration 53.
# [I 2021-07-29 19:31:51,367] Trial 47 pruned. Trial was pruned at iteration 15.
# [I 2021-07-29 19:31:51,595] Trial 48 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:31:51,956] Trial 49 pruned. Trial was pruned at iteration 21.
# [I 2021-07-29 19:31:52,197] Trial 50 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:31:52,415] Trial 51 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:31:52,641] Trial 52 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:31:52,939] Trial 53 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:31:53,176] Trial 54 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:31:53,403] Trial 55 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:31:53,705] Trial 56 pruned. Trial was pruned at iteration 13.
# [I 2021-07-29 19:31:54,006] Trial 57 pruned. Trial was pruned at iteration 16.
# [I 2021-07-29 19:31:54,210] Trial 58 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:31:55,361] Trial 59 finished with value: 0.863295636220638 and parameters: {'max_depth': 9, 'colsample_bytree': 0.5787318392516824, 'subsample': 0.576141312951802, 'min_child_samples': 44, 'lambda_l1': 0.006558765857258209, 'lambda_l2': 0.005703296631966593}. Best is trial 11 with value: 0.8634175138582297.
# [I 2021-07-29 19:31:56,227] Trial 60 pruned. Trial was pruned at iteration 91.
# [I 2021-07-29 19:31:56,729] Trial 61 pruned. Trial was pruned at iteration 40.
# [I 2021-07-29 19:31:57,360] Trial 62 pruned. Trial was pruned at iteration 57.
# [I 2021-07-29 19:31:57,889] Trial 63 pruned. Trial was pruned at iteration 41.
# [I 2021-07-29 19:31:58,164] Trial 64 pruned. Trial was pruned at iteration 16.
# [I 2021-07-29 19:31:58,679] Trial 65 pruned. Trial was pruned at iteration 40.
# [I 2021-07-29 19:31:58,933] Trial 66 pruned. Trial was pruned at iteration 13.
# [I 2021-07-29 19:31:59,158] Trial 67 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:31:59,388] Trial 68 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:31:59,663] Trial 69 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:31:59,944] Trial 70 pruned. Trial was pruned at iteration 16.
# [I 2021-07-29 19:32:00,216] Trial 71 pruned. Trial was pruned at iteration 15.
# [I 2021-07-29 19:32:00,720] Trial 72 pruned. Trial was pruned at iteration 39.
# [I 2021-07-29 19:32:01,633] Trial 73 pruned. Trial was pruned at iteration 91.
# [I 2021-07-29 19:32:01,875] Trial 74 pruned. Trial was pruned at iteration 12.
# [I 2021-07-29 19:32:02,123] Trial 75 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:02,670] Trial 76 pruned. Trial was pruned at iteration 35.
# [I 2021-07-29 19:32:02,909] Trial 77 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:03,227] Trial 78 pruned. Trial was pruned at iteration 16.
# [I 2021-07-29 19:32:03,502] Trial 79 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:03,849] Trial 80 pruned. Trial was pruned at iteration 23.
# [I 2021-07-29 19:32:04,078] Trial 81 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:04,351] Trial 82 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:04,570] Trial 83 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:04,770] Trial 84 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:05,412] Trial 85 pruned. Trial was pruned at iteration 53.
# [I 2021-07-29 19:32:05,633] Trial 86 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:05,890] Trial 87 pruned. Trial was pruned at iteration 13.
# [I 2021-07-29 19:32:06,176] Trial 88 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:06,408] Trial 89 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:06,682] Trial 90 pruned. Trial was pruned at iteration 16.
# [I 2021-07-29 19:32:06,972] Trial 91 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:07,205] Trial 92 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:07,436] Trial 93 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:07,670] Trial 94 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:07,979] Trial 95 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:08,245] Trial 96 pruned. Trial was pruned at iteration 14.
# [I 2021-07-29 19:32:08,473] Trial 97 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:09,405] Trial 98 pruned. Trial was pruned at iteration 91.
# [I 2021-07-29 19:32:09,651] Trial 99 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:09,924] Trial 100 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:10,162] Trial 101 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:10,397] Trial 102 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:10,635] Trial 103 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:10,914] Trial 104 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:11,149] Trial 105 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:11,385] Trial 106 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:12,358] Trial 107 pruned. Trial was pruned at iteration 79.
# [I 2021-07-29 19:32:12,626] Trial 108 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:13,186] Trial 109 pruned. Trial was pruned at iteration 40.
# [I 2021-07-29 19:32:13,420] Trial 110 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:13,720] Trial 111 pruned. Trial was pruned at iteration 13.
# [I 2021-07-29 19:32:14,004] Trial 112 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:14,286] Trial 113 pruned. Trial was pruned at iteration 13.
# [I 2021-07-29 19:32:14,528] Trial 114 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:15,131] Trial 115 pruned. Trial was pruned at iteration 40.
# [I 2021-07-29 19:32:15,376] Trial 116 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:15,614] Trial 117 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:15,930] Trial 118 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:16,171] Trial 119 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:16,572] Trial 120 pruned. Trial was pruned at iteration 22.
# [I 2021-07-29 19:32:17,148] Trial 121 pruned. Trial was pruned at iteration 37.
# [I 2021-07-29 19:32:17,695] Trial 122 pruned. Trial was pruned at iteration 39.
# [I 2021-07-29 19:32:18,096] Trial 123 pruned. Trial was pruned at iteration 23.
# [I 2021-07-29 19:32:18,609] Trial 124 pruned. Trial was pruned at iteration 34.
# [I 2021-07-29 19:32:18,851] Trial 125 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:19,539] Trial 126 pruned. Trial was pruned at iteration 55.
# [I 2021-07-29 19:32:19,790] Trial 127 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:20,123] Trial 128 pruned. Trial was pruned at iteration 17.
# [I 2021-07-29 19:32:21,171] Trial 129 finished with value: 0.8632130571755562 and parameters: {'max_depth': 7, 'colsample_bytree': 0.5704934967149888, 'subsample': 0.9694545697289217, 'min_child_samples': 38, 'lambda_l1': 0.27294119340384015, 'lambda_l2': 1.4678337160531477e-08}. Best is trial 11 with value: 0.8634175138582297.
# [I 2021-07-29 19:32:21,654] Trial 130 pruned. Trial was pruned at iteration 37.
# [I 2021-07-29 19:32:22,339] Trial 131 pruned. Trial was pruned at iteration 59.
# [I 2021-07-29 19:32:22,660] Trial 132 pruned. Trial was pruned at iteration 21.
# [I 2021-07-29 19:32:22,905] Trial 133 pruned. Trial was pruned at iteration 12.
# [I 2021-07-29 19:32:23,302] Trial 134 pruned. Trial was pruned at iteration 22.
# [I 2021-07-29 19:32:23,515] Trial 135 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:24,271] Trial 136 pruned. Trial was pruned at iteration 52.
# [I 2021-07-29 19:32:24,575] Trial 137 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:24,870] Trial 138 pruned. Trial was pruned at iteration 16.
# [I 2021-07-29 19:32:25,189] Trial 139 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:25,527] Trial 140 pruned. Trial was pruned at iteration 16.
# [I 2021-07-29 19:32:26,389] Trial 141 pruned. Trial was pruned at iteration 76.
# [I 2021-07-29 19:32:26,920] Trial 142 pruned. Trial was pruned at iteration 40.
# [I 2021-07-29 19:32:27,308] Trial 143 pruned. Trial was pruned at iteration 23.
# [I 2021-07-29 19:32:27,552] Trial 144 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:28,028] Trial 145 pruned. Trial was pruned at iteration 36.
# [I 2021-07-29 19:32:28,583] Trial 146 pruned. Trial was pruned at iteration 40.
# [I 2021-07-29 19:32:28,825] Trial 147 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:29,112] Trial 148 pruned. Trial was pruned at iteration 12.
# [I 2021-07-29 19:32:29,489] Trial 149 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:32:29,739] Trial 150 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:30,294] Trial 151 pruned. Trial was pruned at iteration 40.
# [I 2021-07-29 19:32:30,548] Trial 152 pruned. Trial was pruned at iteration 12.
# [I 2021-07-29 19:32:31,059] Trial 153 pruned. Trial was pruned at iteration 40.
# [I 2021-07-29 19:32:31,374] Trial 154 pruned. Trial was pruned at iteration 13.
# [I 2021-07-29 19:32:31,882] Trial 155 pruned. Trial was pruned at iteration 40.
# [I 2021-07-29 19:32:32,135] Trial 156 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:32,390] Trial 157 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:32,715] Trial 158 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:32:33,825] Trial 159 finished with value: 0.8634332460000923 and parameters: {'max_depth': 8, 'colsample_bytree': 0.5513601540200093, 'subsample': 0.8451505685678817, 'min_child_samples': 37, 'lambda_l1': 0.00017967416002749443, 'lambda_l2': 0.0006178201427094663}. Best is trial 159 with value: 0.8634332460000923.
# [I 2021-07-29 19:32:34,064] Trial 160 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:34,415] Trial 161 pruned. Trial was pruned at iteration 21.
# [I 2021-07-29 19:32:35,562] Trial 162 finished with value: 0.8634888365505201 and parameters: {'max_depth': 8, 'colsample_bytree': 0.5408815427763269, 'subsample': 0.8466638436024809, 'min_child_samples': 37, 'lambda_l1': 0.0001634213220638466, 'lambda_l2': 0.0019856133446647076}. Best is trial 162 with value: 0.8634888365505201.
# [I 2021-07-29 19:32:36,144] Trial 163 pruned. Trial was pruned at iteration 44.
# [I 2021-07-29 19:32:36,430] Trial 164 pruned. Trial was pruned at iteration 13.
# [I 2021-07-29 19:32:36,698] Trial 165 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:36,940] Trial 166 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:37,905] Trial 167 finished with value: 0.8630888432338913 and parameters: {'max_depth': 9, 'colsample_bytree': 0.5348729869639643, 'subsample': 0.8071009500195986, 'min_child_samples': 41, 'lambda_l1': 0.00019497259568402055, 'lambda_l2': 0.00872660138998645}. Best is trial 162 with value: 0.8634888365505201.
# [I 2021-07-29 19:32:38,141] Trial 168 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:38,695] Trial 169 pruned. Trial was pruned at iteration 42.
# [I 2021-07-29 19:32:39,039] Trial 170 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:32:39,665] Trial 171 pruned. Trial was pruned at iteration 48.
# [I 2021-07-29 19:32:39,995] Trial 172 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:32:40,361] Trial 173 pruned. Trial was pruned at iteration 23.
# [I 2021-07-29 19:32:40,689] Trial 174 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:40,939] Trial 175 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:41,263] Trial 176 pruned. Trial was pruned at iteration 18.
# [I 2021-07-29 19:32:41,842] Trial 177 pruned. Trial was pruned at iteration 40.
# [I 2021-07-29 19:32:42,105] Trial 178 pruned. Trial was pruned at iteration 12.
# [I 2021-07-29 19:32:42,349] Trial 179 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:42,651] Trial 180 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:43,018] Trial 181 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:32:43,713] Trial 182 pruned. Trial was pruned at iteration 54.
# [I 2021-07-29 19:32:43,975] Trial 183 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:44,302] Trial 184 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:32:44,554] Trial 185 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:44,834] Trial 186 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:45,163] Trial 187 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:32:45,405] Trial 188 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:45,786] Trial 189 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:32:46,322] Trial 190 pruned. Trial was pruned at iteration 44.
# [I 2021-07-29 19:32:46,912] Trial 191 pruned. Trial was pruned at iteration 44.
# [I 2021-07-29 19:32:47,554] Trial 192 pruned. Trial was pruned at iteration 55.
# [I 2021-07-29 19:32:48,107] Trial 193 pruned. Trial was pruned at iteration 41.
# [I 2021-07-29 19:32:48,875] Trial 194 pruned. Trial was pruned at iteration 68.
# [I 2021-07-29 19:32:49,382] Trial 195 pruned. Trial was pruned at iteration 40.
# [I 2021-07-29 19:32:49,659] Trial 196 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:50,014] Trial 197 pruned. Trial was pruned at iteration 22.
# [I 2021-07-29 19:32:50,650] Trial 198 pruned. Trial was pruned at iteration 49.
# [I 2021-07-29 19:32:50,882] Trial 199 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:51,236] Trial 200 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:32:51,842] Trial 201 pruned. Trial was pruned at iteration 44.
# [I 2021-07-29 19:32:52,424] Trial 202 pruned. Trial was pruned at iteration 49.
# [I 2021-07-29 19:32:52,743] Trial 203 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:52,989] Trial 204 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:53,308] Trial 205 pruned. Trial was pruned at iteration 19.
# [I 2021-07-29 19:32:53,766] Trial 206 pruned. Trial was pruned at iteration 28.
# [I 2021-07-29 19:32:54,399] Trial 207 pruned. Trial was pruned at iteration 44.
# [I 2021-07-29 19:32:54,710] Trial 208 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:55,097] Trial 209 pruned. Trial was pruned at iteration 26.
# [I 2021-07-29 19:32:55,738] Trial 210 pruned. Trial was pruned at iteration 53.
# [I 2021-07-29 19:32:56,064] Trial 211 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:32:56,406] Trial 212 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:32:56,844] Trial 213 pruned. Trial was pruned at iteration 22.
# [I 2021-07-29 19:32:57,186] Trial 214 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:32:57,519] Trial 215 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:32:57,841] Trial 216 pruned. Trial was pruned at iteration 12.
# [I 2021-07-29 19:32:58,136] Trial 217 pruned. Trial was pruned at iteration 15.
# [I 2021-07-29 19:32:58,388] Trial 218 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:58,702] Trial 219 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:32:59,009] Trial 220 pruned. Trial was pruned at iteration 17.
# [I 2021-07-29 19:32:59,368] Trial 221 pruned. Trial was pruned at iteration 23.
# [I 2021-07-29 19:33:00,572] Trial 222 finished with value: 0.8632332321558609 and parameters: {'max_depth': 10, 'colsample_bytree': 0.5390028716186647, 'subsample': 0.7853783106800706, 'min_child_samples': 37, 'lambda_l1': 0.05313781482366988, 'lambda_l2': 0.005945187588882656}. Best is trial 162 with value: 0.8634888365505201.
# [I 2021-07-29 19:33:00,828] Trial 223 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:01,985] Trial 224 finished with value: 0.8632381046599916 and parameters: {'max_depth': 10, 'colsample_bytree': 0.5439958219028861, 'subsample': 0.9448290421059372, 'min_child_samples': 41, 'lambda_l1': 0.017943148817174612, 'lambda_l2': 0.007468743581016311}. Best is trial 162 with value: 0.8634888365505201.
# [I 2021-07-29 19:33:02,321] Trial 225 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:33:02,720] Trial 226 pruned. Trial was pruned at iteration 27.
# [I 2021-07-29 19:33:02,977] Trial 227 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:03,365] Trial 228 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:33:04,056] Trial 229 pruned. Trial was pruned at iteration 57.
# [I 2021-07-29 19:33:04,476] Trial 230 pruned. Trial was pruned at iteration 26.
# [I 2021-07-29 19:33:05,212] Trial 231 pruned. Trial was pruned at iteration 66.
# [I 2021-07-29 19:33:05,547] Trial 232 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:33:05,791] Trial 233 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:06,034] Trial 234 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:06,316] Trial 235 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:06,564] Trial 236 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:06,831] Trial 237 pruned. Trial was pruned at iteration 12.
# [I 2021-07-29 19:33:07,149] Trial 238 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:07,446] Trial 239 pruned. Trial was pruned at iteration 12.
# [I 2021-07-29 19:33:07,788] Trial 240 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:33:08,200] Trial 241 pruned. Trial was pruned at iteration 23.
# [I 2021-07-29 19:33:08,542] Trial 242 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:33:09,360] Trial 243 pruned. Trial was pruned at iteration 72.
# [I 2021-07-29 19:33:09,614] Trial 244 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:09,866] Trial 245 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:10,244] Trial 246 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:33:10,614] Trial 247 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:33:10,957] Trial 248 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:33:11,255] Trial 249 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:11,505] Trial 250 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:11,877] Trial 251 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:33:12,494] Trial 252 pruned. Trial was pruned at iteration 40.
# [I 2021-07-29 19:33:12,740] Trial 253 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:13,087] Trial 254 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:33:13,491] Trial 255 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:33:13,764] Trial 256 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:14,250] Trial 257 pruned. Trial was pruned at iteration 29.
# [I 2021-07-29 19:33:14,507] Trial 258 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:15,323] Trial 259 pruned. Trial was pruned at iteration 54.
# [I 2021-07-29 19:33:15,655] Trial 260 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:16,087] Trial 261 pruned. Trial was pruned at iteration 27.
# [I 2021-07-29 19:33:16,479] Trial 262 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:33:16,753] Trial 263 pruned. Trial was pruned at iteration 12.
# [I 2021-07-29 19:33:17,007] Trial 264 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:17,743] Trial 265 pruned. Trial was pruned at iteration 44.
# [I 2021-07-29 19:33:17,999] Trial 266 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:18,550] Trial 267 pruned. Trial was pruned at iteration 34.
# [I 2021-07-29 19:33:19,070] Trial 268 pruned. Trial was pruned at iteration 22.
# [I 2021-07-29 19:33:20,015] Trial 269 pruned. Trial was pruned at iteration 65.
# [I 2021-07-29 19:33:20,275] Trial 270 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:20,590] Trial 271 pruned. Trial was pruned at iteration 15.
# [I 2021-07-29 19:33:20,997] Trial 272 pruned. Trial was pruned at iteration 21.
# [I 2021-07-29 19:33:21,593] Trial 273 pruned. Trial was pruned at iteration 45.
# [I 2021-07-29 19:33:21,940] Trial 274 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:33:22,201] Trial 275 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:22,447] Trial 276 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:22,700] Trial 277 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:22,996] Trial 278 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:23,243] Trial 279 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:23,489] Trial 280 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:23,752] Trial 281 pruned. Trial was pruned at iteration 13.
# [I 2021-07-29 19:33:24,136] Trial 282 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:33:24,431] Trial 283 pruned. Trial was pruned at iteration 16.
# [I 2021-07-29 19:33:24,671] Trial 284 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:25,020] Trial 285 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:33:25,264] Trial 286 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:25,508] Trial 287 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:25,926] Trial 288 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:33:26,177] Trial 289 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:26,744] Trial 290 pruned. Trial was pruned at iteration 41.
# [I 2021-07-29 19:33:27,077] Trial 291 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:33:27,324] Trial 292 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:27,582] Trial 293 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:27,881] Trial 294 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:28,160] Trial 295 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:28,584] Trial 296 pruned. Trial was pruned at iteration 26.
# [I 2021-07-29 19:33:28,863] Trial 297 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:29,442] Trial 298 pruned. Trial was pruned at iteration 42.
# [I 2021-07-29 19:33:29,826] Trial 299 pruned. Trial was pruned at iteration 12.
# [I 2021-07-29 19:33:30,091] Trial 300 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:30,333] Trial 301 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:30,585] Trial 302 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:30,953] Trial 303 pruned. Trial was pruned at iteration 19.
# [I 2021-07-29 19:33:31,438] Trial 304 pruned. Trial was pruned at iteration 37.
# [I 2021-07-29 19:33:31,895] Trial 305 pruned. Trial was pruned at iteration 23.
# [I 2021-07-29 19:33:32,162] Trial 306 pruned. Trial was pruned at iteration 12.
# [I 2021-07-29 19:33:32,452] Trial 307 pruned. Trial was pruned at iteration 15.
# [I 2021-07-29 19:33:32,753] Trial 308 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:33,025] Trial 309 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:33,402] Trial 310 pruned. Trial was pruned at iteration 23.
# [I 2021-07-29 19:33:33,855] Trial 311 pruned. Trial was pruned at iteration 26.
# [I 2021-07-29 19:33:34,151] Trial 312 pruned. Trial was pruned at iteration 15.
# [I 2021-07-29 19:33:34,431] Trial 313 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:34,786] Trial 314 pruned. Trial was pruned at iteration 16.
# [I 2021-07-29 19:33:35,008] Trial 315 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:35,299] Trial 316 pruned. Trial was pruned at iteration 15.
# [I 2021-07-29 19:33:35,675] Trial 317 pruned. Trial was pruned at iteration 19.
# [I 2021-07-29 19:33:36,039] Trial 318 pruned. Trial was pruned at iteration 23.
# [I 2021-07-29 19:33:36,291] Trial 319 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:36,540] Trial 320 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:37,045] Trial 321 pruned. Trial was pruned at iteration 35.
# [I 2021-07-29 19:33:37,304] Trial 322 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:37,590] Trial 323 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:37,847] Trial 324 pruned. Trial was pruned at iteration 12.
# [I 2021-07-29 19:33:38,101] Trial 325 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:38,450] Trial 326 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:33:38,725] Trial 327 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:39,005] Trial 328 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:39,344] Trial 329 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:33:39,646] Trial 330 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:40,345] Trial 331 pruned. Trial was pruned at iteration 45.
# [I 2021-07-29 19:33:40,788] Trial 332 pruned. Trial was pruned at iteration 26.
# [I 2021-07-29 19:33:41,082] Trial 333 pruned. Trial was pruned at iteration 12.
# [I 2021-07-29 19:33:41,355] Trial 334 pruned. Trial was pruned at iteration 12.
# [I 2021-07-29 19:33:41,610] Trial 335 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:42,201] Trial 336 pruned. Trial was pruned at iteration 42.
# [I 2021-07-29 19:33:42,619] Trial 337 pruned. Trial was pruned at iteration 28.
# [I 2021-07-29 19:33:43,223] Trial 338 pruned. Trial was pruned at iteration 45.
# [I 2021-07-29 19:33:43,511] Trial 339 pruned. Trial was pruned at iteration 13.
# [I 2021-07-29 19:33:43,890] Trial 340 pruned. Trial was pruned at iteration 16.
# [I 2021-07-29 19:33:44,394] Trial 341 pruned. Trial was pruned at iteration 33.
# [I 2021-07-29 19:33:44,666] Trial 342 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:45,021] Trial 343 pruned. Trial was pruned at iteration 13.
# [I 2021-07-29 19:33:45,304] Trial 344 pruned. Trial was pruned at iteration 12.
# [I 2021-07-29 19:33:45,585] Trial 345 pruned. Trial was pruned at iteration 12.
# [I 2021-07-29 19:33:45,885] Trial 346 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:46,161] Trial 347 pruned. Trial was pruned at iteration 12.
# [I 2021-07-29 19:33:46,445] Trial 348 pruned. Trial was pruned at iteration 13.
# [I 2021-07-29 19:33:46,709] Trial 349 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:47,001] Trial 350 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:47,276] Trial 351 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:47,671] Trial 352 pruned. Trial was pruned at iteration 19.
# [I 2021-07-29 19:33:48,113] Trial 353 pruned. Trial was pruned at iteration 23.
# [I 2021-07-29 19:33:48,462] Trial 354 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:33:48,748] Trial 355 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:49,083] Trial 356 pruned. Trial was pruned at iteration 12.
# [I 2021-07-29 19:33:49,380] Trial 357 pruned. Trial was pruned at iteration 12.
# [I 2021-07-29 19:33:49,709] Trial 358 pruned. Trial was pruned at iteration 14.
# [I 2021-07-29 19:33:50,031] Trial 359 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:50,372] Trial 360 pruned. Trial was pruned at iteration 12.
# [I 2021-07-29 19:33:50,706] Trial 361 pruned. Trial was pruned at iteration 16.
# [I 2021-07-29 19:33:51,041] Trial 362 pruned. Trial was pruned at iteration 15.
# [I 2021-07-29 19:33:51,591] Trial 363 pruned. Trial was pruned at iteration 40.
# [I 2021-07-29 19:33:51,951] Trial 364 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:33:52,254] Trial 365 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:52,757] Trial 366 pruned. Trial was pruned at iteration 29.
# [I 2021-07-29 19:33:53,395] Trial 367 pruned. Trial was pruned at iteration 46.
# [I 2021-07-29 19:33:53,654] Trial 368 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:54,015] Trial 369 pruned. Trial was pruned at iteration 19.
# [I 2021-07-29 19:33:54,386] Trial 370 pruned. Trial was pruned at iteration 12.
# [I 2021-07-29 19:33:54,754] Trial 371 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:33:55,016] Trial 372 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:55,332] Trial 373 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:55,592] Trial 374 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:55,981] Trial 375 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:33:56,257] Trial 376 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:56,579] Trial 377 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:57,027] Trial 378 pruned. Trial was pruned at iteration 29.
# [I 2021-07-29 19:33:57,618] Trial 379 pruned. Trial was pruned at iteration 40.
# [I 2021-07-29 19:33:58,006] Trial 380 pruned. Trial was pruned at iteration 22.
# [I 2021-07-29 19:33:58,292] Trial 381 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:58,732] Trial 382 pruned. Trial was pruned at iteration 23.
# [I 2021-07-29 19:33:58,989] Trial 383 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:33:59,330] Trial 384 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:33:59,889] Trial 385 pruned. Trial was pruned at iteration 33.
# [I 2021-07-29 19:34:00,165] Trial 386 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:00,555] Trial 387 pruned. Trial was pruned at iteration 17.
# [I 2021-07-29 19:34:01,219] Trial 388 pruned. Trial was pruned at iteration 34.
# [I 2021-07-29 19:34:01,518] Trial 389 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:01,788] Trial 390 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:02,080] Trial 391 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:02,451] Trial 392 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:34:02,864] Trial 393 pruned. Trial was pruned at iteration 22.
# [I 2021-07-29 19:34:03,459] Trial 394 pruned. Trial was pruned at iteration 46.
# [I 2021-07-29 19:34:03,792] Trial 395 pruned. Trial was pruned at iteration 16.
# [I 2021-07-29 19:34:04,283] Trial 396 pruned. Trial was pruned at iteration 26.
# [I 2021-07-29 19:34:04,543] Trial 397 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:04,823] Trial 398 pruned. Trial was pruned at iteration 12.
# [I 2021-07-29 19:34:05,122] Trial 399 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:05,397] Trial 400 pruned. Trial was pruned at iteration 12.
# [I 2021-07-29 19:34:05,861] Trial 401 pruned. Trial was pruned at iteration 30.
# [I 2021-07-29 19:34:06,227] Trial 402 pruned. Trial was pruned at iteration 23.
# [I 2021-07-29 19:34:06,488] Trial 403 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:06,747] Trial 404 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:07,041] Trial 405 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:07,351] Trial 406 pruned. Trial was pruned at iteration 16.
# [I 2021-07-29 19:34:07,977] Trial 407 pruned. Trial was pruned at iteration 44.
# [I 2021-07-29 19:34:08,248] Trial 408 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:08,519] Trial 409 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:08,782] Trial 410 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:09,213] Trial 411 pruned. Trial was pruned at iteration 23.
# [I 2021-07-29 19:34:09,561] Trial 412 pruned. Trial was pruned at iteration 19.
# [I 2021-07-29 19:34:09,865] Trial 413 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:10,103] Trial 414 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:10,398] Trial 415 pruned. Trial was pruned at iteration 13.
# [I 2021-07-29 19:34:10,654] Trial 416 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:11,557] Trial 417 pruned. Trial was pruned at iteration 66.
# [I 2021-07-29 19:34:11,831] Trial 418 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:12,167] Trial 419 pruned. Trial was pruned at iteration 13.
# [I 2021-07-29 19:34:12,443] Trial 420 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:12,750] Trial 421 pruned. Trial was pruned at iteration 13.
# [I 2021-07-29 19:34:13,046] Trial 422 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:13,476] Trial 423 pruned. Trial was pruned at iteration 22.
# [I 2021-07-29 19:34:13,747] Trial 424 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:14,188] Trial 425 pruned. Trial was pruned at iteration 25.
# [I 2021-07-29 19:34:14,451] Trial 426 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:14,734] Trial 427 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:15,091] Trial 428 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:34:15,505] Trial 429 pruned. Trial was pruned at iteration 22.
# [I 2021-07-29 19:34:15,763] Trial 430 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:16,033] Trial 431 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:16,321] Trial 432 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:16,594] Trial 433 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:16,846] Trial 434 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:17,177] Trial 435 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:17,581] Trial 436 pruned. Trial was pruned at iteration 22.
# [I 2021-07-29 19:34:17,925] Trial 437 pruned. Trial was pruned at iteration 19.
# [I 2021-07-29 19:34:18,233] Trial 438 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:18,510] Trial 439 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:18,802] Trial 440 pruned. Trial was pruned at iteration 13.
# [I 2021-07-29 19:34:19,066] Trial 441 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:19,433] Trial 442 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:19,695] Trial 443 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:20,085] Trial 444 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:34:20,765] Trial 445 pruned. Trial was pruned at iteration 46.
# [I 2021-07-29 19:34:21,085] Trial 446 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:21,469] Trial 447 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:34:21,746] Trial 448 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:22,104] Trial 449 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:34:22,385] Trial 450 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:22,777] Trial 451 pruned. Trial was pruned at iteration 19.
# [I 2021-07-29 19:34:23,063] Trial 452 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:23,334] Trial 453 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:23,938] Trial 454 pruned. Trial was pruned at iteration 41.
# [I 2021-07-29 19:34:24,177] Trial 455 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:24,449] Trial 456 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:24,851] Trial 457 pruned. Trial was pruned at iteration 23.
# [I 2021-07-29 19:34:25,107] Trial 458 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:25,370] Trial 459 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:25,984] Trial 460 pruned. Trial was pruned at iteration 41.
# [I 2021-07-29 19:34:26,251] Trial 461 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:26,807] Trial 462 pruned. Trial was pruned at iteration 40.
# [I 2021-07-29 19:34:27,095] Trial 463 pruned. Trial was pruned at iteration 12.
# [I 2021-07-29 19:34:27,357] Trial 464 pruned. Trial was pruned at iteration 12.
# [I 2021-07-29 19:34:27,732] Trial 465 pruned. Trial was pruned at iteration 18.
# [I 2021-07-29 19:34:28,005] Trial 466 pruned. Trial was pruned at iteration 12.
# [I 2021-07-29 19:34:28,359] Trial 467 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:34:29,092] Trial 468 pruned. Trial was pruned at iteration 53.
# [I 2021-07-29 19:34:29,420] Trial 469 pruned. Trial was pruned at iteration 18.
# [I 2021-07-29 19:34:29,734] Trial 470 pruned. Trial was pruned at iteration 12.
# [I 2021-07-29 19:34:29,999] Trial 471 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:30,372] Trial 472 pruned. Trial was pruned at iteration 22.
# [I 2021-07-29 19:34:30,644] Trial 473 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:30,963] Trial 474 pruned. Trial was pruned at iteration 14.
# [I 2021-07-29 19:34:31,228] Trial 475 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:31,514] Trial 476 pruned. Trial was pruned at iteration 12.
# [I 2021-07-29 19:34:31,894] Trial 477 pruned. Trial was pruned at iteration 15.
# [I 2021-07-29 19:34:32,906] Trial 478 finished with value: 0.8634090870101533 and parameters: {'max_depth': 8, 'colsample_bytree': 0.5325383440482463, 'subsample': 0.7532302747679357, 'min_child_samples': 36, 'lambda_l1': 0.0012957518191876432, 'lambda_l2': 0.000752542874735509}. Best is trial 162 with value: 0.8634888365505201.
# [I 2021-07-29 19:34:33,306] Trial 479 pruned. Trial was pruned at iteration 23.
# [I 2021-07-29 19:34:33,959] Trial 480 pruned. Trial was pruned at iteration 49.
# [I 2021-07-29 19:34:34,285] Trial 481 pruned. Trial was pruned at iteration 16.
# [I 2021-07-29 19:34:34,654] Trial 482 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:34:35,279] Trial 483 pruned. Trial was pruned at iteration 45.
# [I 2021-07-29 19:34:36,305] Trial 484 finished with value: 0.8632408956784854 and parameters: {'max_depth': 8, 'colsample_bytree': 0.5423135772889808, 'subsample': 0.754786212313595, 'min_child_samples': 36, 'lambda_l1': 0.000504841388522611, 'lambda_l2': 0.0005671425238979671}. Best is trial 162 with value: 0.8634888365505201.
# [I 2021-07-29 19:34:36,549] Trial 485 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:36,951] Trial 486 pruned. Trial was pruned at iteration 26.
# [I 2021-07-29 19:34:37,285] Trial 487 pruned. Trial was pruned at iteration 14.
# [I 2021-07-29 19:34:37,631] Trial 488 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:34:37,897] Trial 489 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:38,158] Trial 490 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:38,464] Trial 491 pruned. Trial was pruned at iteration 13.
# [I 2021-07-29 19:34:38,732] Trial 492 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:39,373] Trial 493 pruned. Trial was pruned at iteration 45.
# [I 2021-07-29 19:34:39,631] Trial 494 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:39,888] Trial 495 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:40,152] Trial 496 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:40,433] Trial 497 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:40,707] Trial 498 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:41,048] Trial 499 pruned. Trial was pruned at iteration 19.
# [I 2021-07-29 19:34:41,400] Trial 500 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:41,687] Trial 501 pruned. Trial was pruned at iteration 13.
# [I 2021-07-29 19:34:41,968] Trial 502 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:42,286] Trial 503 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:42,658] Trial 504 pruned. Trial was pruned at iteration 23.
# [I 2021-07-29 19:34:43,005] Trial 505 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:34:43,314] Trial 506 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:43,631] Trial 507 pruned. Trial was pruned at iteration 17.
# [I 2021-07-29 19:34:43,981] Trial 508 pruned. Trial was pruned at iteration 19.
# [I 2021-07-29 19:34:44,341] Trial 509 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:44,695] Trial 510 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:34:44,964] Trial 511 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:45,399] Trial 512 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:34:45,757] Trial 513 pruned. Trial was pruned at iteration 16.
# [I 2021-07-29 19:34:46,229] Trial 514 pruned. Trial was pruned at iteration 27.
# [I 2021-07-29 19:34:46,659] Trial 515 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:34:46,933] Trial 516 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:47,208] Trial 517 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:47,959] Trial 518 pruned. Trial was pruned at iteration 49.
# [I 2021-07-29 19:34:48,225] Trial 519 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:48,611] Trial 520 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:34:48,920] Trial 521 pruned. Trial was pruned at iteration 12.
# [I 2021-07-29 19:34:49,209] Trial 522 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:49,666] Trial 523 pruned. Trial was pruned at iteration 28.
# [I 2021-07-29 19:34:49,950] Trial 524 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:50,284] Trial 525 pruned. Trial was pruned at iteration 16.
# [I 2021-07-29 19:34:50,565] Trial 526 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:50,887] Trial 527 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:51,340] Trial 528 pruned. Trial was pruned at iteration 29.
# [I 2021-07-29 19:34:51,640] Trial 529 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:51,973] Trial 530 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:52,435] Trial 531 pruned. Trial was pruned at iteration 24.
# [I 2021-07-29 19:34:52,752] Trial 532 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:53,083] Trial 533 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:34:53,393] Trial 534 pruned. Trial was pruned at iteration 14.
# [I 2021-07-29 19:34:53,791] Trial 535 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:34:54,131] Trial 536 pruned. Trial was pruned at iteration 10.
# ...
# [I 2021-07-29 19:36:26,921] Trial 804 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:27,216] Trial 805 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:27,581] Trial 806 pruned. Trial was pruned at iteration 13.
# [I 2021-07-29 19:36:27,860] Trial 807 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:28,322] Trial 808 pruned. Trial was pruned at iteration 25.
# [I 2021-07-29 19:36:28,704] Trial 809 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:28,997] Trial 810 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:29,357] Trial 811 pruned. Trial was pruned at iteration 18.
# [I 2021-07-29 19:36:29,643] Trial 812 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:30,146] Trial 813 pruned. Trial was pruned at iteration 26.
# [I 2021-07-29 19:36:30,416] Trial 814 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:30,711] Trial 815 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:31,023] Trial 816 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:31,360] Trial 817 pruned. Trial was pruned at iteration 15.
# [I 2021-07-29 19:36:31,662] Trial 818 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:32,045] Trial 819 pruned. Trial was pruned at iteration 15.
# [I 2021-07-29 19:36:32,341] Trial 820 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:32,996] Trial 821 pruned. Trial was pruned at iteration 43.
# [I 2021-07-29 19:36:33,318] Trial 822 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:33,648] Trial 823 pruned. Trial was pruned at iteration 15.
# [I 2021-07-29 19:36:33,970] Trial 824 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:34,331] Trial 825 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:34,641] Trial 826 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:35,033] Trial 827 pruned. Trial was pruned at iteration 19.
# [I 2021-07-29 19:36:35,719] Trial 828 pruned. Trial was pruned at iteration 46.
# [I 2021-07-29 19:36:36,003] Trial 829 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:36,292] Trial 830 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:36,600] Trial 831 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:37,009] Trial 832 pruned. Trial was pruned at iteration 23.
# [I 2021-07-29 19:36:37,329] Trial 833 pruned. Trial was pruned at iteration 13.
# [I 2021-07-29 19:36:37,670] Trial 834 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:37,954] Trial 835 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:38,267] Trial 836 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:38,564] Trial 837 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:39,051] Trial 838 pruned. Trial was pruned at iteration 19.
# [I 2021-07-29 19:36:39,474] Trial 839 pruned. Trial was pruned at iteration 23.
# [I 2021-07-29 19:36:39,907] Trial 840 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:36:40,172] Trial 841 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:40,461] Trial 842 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:40,801] Trial 843 pruned. Trial was pruned at iteration 15.
# [I 2021-07-29 19:36:41,133] Trial 844 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:41,525] Trial 845 pruned. Trial was pruned at iteration 19.
# [I 2021-07-29 19:36:41,852] Trial 846 pruned. Trial was pruned at iteration 13.
# [I 2021-07-29 19:36:42,198] Trial 847 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:42,486] Trial 848 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:42,767] Trial 849 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:43,052] Trial 850 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:44,393] Trial 851 finished with value: 0.8631974816646556 and parameters: {'max_depth': 8, 'colsample_bytree': 0.5379979987918995, 'subsample': 0.7758104404171924, 'min_child_samples': 36, 'lambda_l1': 0.00034607997621437757, 'lambda_l2': 0.00042698710405007805}. Best is trial 162 with value: 0.8634888365505201.
# [I 2021-07-29 19:36:44,749] Trial 852 pruned. Trial was pruned at iteration 17.
# [I 2021-07-29 19:36:45,119] Trial 853 pruned. Trial was pruned at iteration 19.
# [I 2021-07-29 19:36:45,405] Trial 854 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:45,748] Trial 855 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:46,155] Trial 856 pruned. Trial was pruned at iteration 23.
# [I 2021-07-29 19:36:46,549] Trial 857 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:36:46,932] Trial 858 pruned. Trial was pruned at iteration 13.
# [I 2021-07-29 19:36:47,279] Trial 859 pruned. Trial was pruned at iteration 15.
# [I 2021-07-29 19:36:47,567] Trial 860 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:47,963] Trial 861 pruned. Trial was pruned at iteration 17.
# [I 2021-07-29 19:36:48,375] Trial 862 pruned. Trial was pruned at iteration 22.
# [I 2021-07-29 19:36:48,678] Trial 863 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:48,959] Trial 864 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:49,256] Trial 865 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:49,692] Trial 866 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:36:50,051] Trial 867 pruned. Trial was pruned at iteration 17.
# [I 2021-07-29 19:36:50,358] Trial 868 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:50,630] Trial 869 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:50,924] Trial 870 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:51,363] Trial 871 pruned. Trial was pruned at iteration 18.
# [I 2021-07-29 19:36:51,697] Trial 872 pruned. Trial was pruned at iteration 14.
# [I 2021-07-29 19:36:52,061] Trial 873 pruned. Trial was pruned at iteration 17.
# [I 2021-07-29 19:36:52,468] Trial 874 pruned. Trial was pruned at iteration 15.
# [I 2021-07-29 19:36:52,753] Trial 875 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:53,043] Trial 876 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:53,320] Trial 877 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:53,654] Trial 878 pruned. Trial was pruned at iteration 13.
# [I 2021-07-29 19:36:54,030] Trial 879 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:36:54,433] Trial 880 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:36:54,806] Trial 881 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:36:55,277] Trial 882 pruned. Trial was pruned at iteration 29.
# [I 2021-07-29 19:36:55,643] Trial 883 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:55,922] Trial 884 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:56,211] Trial 885 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:56,477] Trial 886 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:56,845] Trial 887 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:57,244] Trial 888 pruned. Trial was pruned at iteration 22.
# [I 2021-07-29 19:36:57,859] Trial 889 pruned. Trial was pruned at iteration 43.
# [I 2021-07-29 19:36:58,141] Trial 890 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:58,425] Trial 891 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:58,712] Trial 892 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:59,042] Trial 893 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:59,328] Trial 894 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:59,612] Trial 895 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:36:59,947] Trial 896 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:00,227] Trial 897 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:00,505] Trial 898 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:01,135] Trial 899 pruned. Trial was pruned at iteration 41.
# [I 2021-07-29 19:37:01,487] Trial 900 pruned. Trial was pruned at iteration 17.
# [I 2021-07-29 19:37:01,761] Trial 901 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:02,102] Trial 902 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:02,457] Trial 903 pruned. Trial was pruned at iteration 18.
# [I 2021-07-29 19:37:02,729] Trial 904 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:03,014] Trial 905 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:03,413] Trial 906 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:37:03,701] Trial 907 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:04,011] Trial 908 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:04,392] Trial 909 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:04,769] Trial 910 pruned. Trial was pruned at iteration 18.
# [I 2021-07-29 19:37:05,057] Trial 911 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:05,402] Trial 912 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:05,760] Trial 913 pruned. Trial was pruned at iteration 17.
# [I 2021-07-29 19:37:06,058] Trial 914 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:06,356] Trial 915 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:06,793] Trial 916 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:37:07,086] Trial 917 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:07,457] Trial 918 pruned. Trial was pruned at iteration 18.
# [I 2021-07-29 19:37:07,901] Trial 919 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:37:08,202] Trial 920 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:08,505] Trial 921 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:08,895] Trial 922 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:09,215] Trial 923 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:09,575] Trial 924 pruned. Trial was pruned at iteration 15.
# [I 2021-07-29 19:37:09,927] Trial 925 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:10,300] Trial 926 pruned. Trial was pruned at iteration 17.
# [I 2021-07-29 19:37:10,588] Trial 927 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:10,899] Trial 928 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:11,530] Trial 929 pruned. Trial was pruned at iteration 32.
# [I 2021-07-29 19:37:11,962] Trial 930 pruned. Trial was pruned at iteration 16.
# [I 2021-07-29 19:37:12,314] Trial 931 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:12,665] Trial 932 pruned. Trial was pruned at iteration 13.
# [I 2021-07-29 19:37:12,990] Trial 933 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:13,303] Trial 934 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:13,688] Trial 935 pruned. Trial was pruned at iteration 13.
# [I 2021-07-29 19:37:14,079] Trial 936 pruned. Trial was pruned at iteration 17.
# [I 2021-07-29 19:37:14,393] Trial 937 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:14,764] Trial 938 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:15,076] Trial 939 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:15,377] Trial 940 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:15,745] Trial 941 pruned. Trial was pruned at iteration 15.
# [I 2021-07-29 19:37:16,102] Trial 942 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:16,390] Trial 943 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:16,768] Trial 944 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:37:17,101] Trial 945 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:17,371] Trial 946 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:17,698] Trial 947 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:18,008] Trial 948 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:18,326] Trial 949 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:18,721] Trial 950 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:37:18,998] Trial 951 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:19,487] Trial 952 pruned. Trial was pruned at iteration 22.
# [I 2021-07-29 19:37:19,765] Trial 953 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:20,056] Trial 954 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:20,448] Trial 955 pruned. Trial was pruned at iteration 15.
# [I 2021-07-29 19:37:20,862] Trial 956 pruned. Trial was pruned at iteration 21.
# [I 2021-07-29 19:37:21,142] Trial 957 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:21,452] Trial 958 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:21,771] Trial 959 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:22,140] Trial 960 pruned. Trial was pruned at iteration 20.
# [I 2021-07-29 19:37:22,421] Trial 961 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:22,855] Trial 962 pruned. Trial was pruned at iteration 17.
# [I 2021-07-29 19:37:23,149] Trial 963 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:23,433] Trial 964 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:23,839] Trial 965 pruned. Trial was pruned at iteration 17.
# [I 2021-07-29 19:37:24,382] Trial 966 pruned. Trial was pruned at iteration 37.
# [I 2021-07-29 19:37:24,669] Trial 967 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:25,009] Trial 968 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:25,302] Trial 969 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:25,890] Trial 970 pruned. Trial was pruned at iteration 37.
# [I 2021-07-29 19:37:26,322] Trial 971 pruned. Trial was pruned at iteration 23.
# [I 2021-07-29 19:37:26,608] Trial 972 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:26,938] Trial 973 pruned. Trial was pruned at iteration 13.
# [I 2021-07-29 19:37:27,238] Trial 974 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:27,522] Trial 975 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:27,806] Trial 976 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:28,151] Trial 977 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:28,512] Trial 978 pruned. Trial was pruned at iteration 18.
# [I 2021-07-29 19:37:28,796] Trial 979 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:29,082] Trial 980 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:29,385] Trial 981 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:29,685] Trial 982 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:29,939] Trial 983 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:30,273] Trial 984 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:30,749] Trial 985 pruned. Trial was pruned at iteration 29.
# [I 2021-07-29 19:37:31,083] Trial 986 pruned. Trial was pruned at iteration 14.
# [I 2021-07-29 19:37:31,423] Trial 987 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:31,741] Trial 988 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:32,030] Trial 989 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:32,316] Trial 990 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:32,665] Trial 991 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:32,982] Trial 992 pruned. Trial was pruned at iteration 13.
# [I 2021-07-29 19:37:33,293] Trial 993 pruned. Trial was pruned at iteration 13.
# [I 2021-07-29 19:37:33,603] Trial 994 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:33,942] Trial 995 pruned. Trial was pruned at iteration 15.
# [I 2021-07-29 19:37:34,248] Trial 996 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:34,543] Trial 997 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:34,874] Trial 998 pruned. Trial was pruned at iteration 10.
# [I 2021-07-29 19:37:35,305] Trial 999 pruned. Trial was pruned at iteration 20.

# %%
print("Number of finished trials: {}".format(len(study.trials)))
print("Best trial:")
trial = study.best_trial
print("  Value: {}".format(trial.value))
print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# Number of finished trials: 1000
# Best trial:
#   Value: 0.8634888365505201
#   Params:
#     max_depth: 8
#     colsample_bytree: 0.5408815427763269
#     subsample: 0.8466638436024809
#     min_child_samples: 37
#     lambda_l1: 0.0001634213220638466
#     lambda_l2: 0.0019856133446647076

# %% [markdown]
# ## Optimize n_estimators and learning rate
# - set to high iterations and low learning rate

# %%
param = trial.params
param.update({"learning_rate":0.01,
              "objective": "binary",
              "metric": "auc"})
param
# Out:
# {'max_depth': 8,
#  'colsample_bytree': 0.5408815427763269,
#  'subsample': 0.8466638436024809,
#  'min_child_samples': 37,
#  'lambda_l1': 0.0001634213220638466,
#  'lambda_l2': 0.0019856133446647076,
#  'learning_rate': 0.01,
#  'objective': 'binary',
#  'metric': 'auc'}

# %%
cv_scores = lgb.cv(param, dtrain, 10000, nfold  = 5, early_stopping_rounds = 50,verbose_eval=False)['auc-mean']

# %%
print(f"Best Iteration {len(cv_scores)} at {cv_scores[-1]}")
# Out:
# Best Iteration 896 at 0.8644408064138457

# %% [markdown]
# # Train and export

# %%
best_param = {
    'max_depth': 8,
    'colsample_bytree': 0.5408815427763269,
    'subsample': 0.8466638436024809,
    'min_child_samples': 37,
    'lambda_l1': 0.0001634213220638466,
    'lambda_l2': 0.0019856133446647076,
    'learning_rate': 0.01,
    'objective': 'binary',
    'metric': 'auc',
    "num_iterations":896
}

# %%
model = lgb.LGBMClassifier()
model.set_params(**best_param)
model.fit(X,y)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None,
#                colsample_bytree=0.5408815427763269, importance_type='split',
#                lambda_l1=0.0001634213220638466, lambda_l2=0.0019856133446647076,
#                learning_rate=0.01, max_depth=8, metric='auc',
#                min_child_samples=37, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_iterations=896, num_leaves=31,
#                objective='binary', random_state=None, reg_alpha=0.0,
#                reg_lambda=0.0, silent=True, subsample=0.8466638436024809,
#                subsample_for_bin=200000, subsample_freq=0)

# %%
import joblib
joblib.dump(model, r"C:\Users\tanch\Documents\Coding Competitions\DataDriven\Flu Shot Learning\local\model\lightgbm seasonsal_vaccine 0.pkl")
# gbm_pickle = joblib.load(r"C:\Users\tanch\Documents\Coding Competitions\DataDriven\Flu Shot Learning\local\model\lightgbm 0.pkl")
# Out:
# ['C:\\Users\\tanch\\Documents\\Coding Competitions\\DataDriven\\Flu Shot Learning\\local\\model\\lightgbm seasonsal_vaccine 0.pkl']
